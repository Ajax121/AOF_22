# %%
inp = open('3.txt','r').readlines()

# %%
import re
lst = []
for num in inp:
    lst.append((re.sub('\n','',num)))

# %%
lst
# Out:
# ['DsPhSBQQQhqmBDhPDsFwjwsLjlRjlttvjvvtRb',
#  'rNJMNNbrHrtjHLHjvwtg',
#  'fNbNzZdrZnMnMPnQShFPDmnqFm',
#  'QWVCFfQffgQCVZzVVpHsHJBqtpspJFRHqq',
#  'mwDbmnnGNlNcwNDDNRbnNDlJTpBJBtJGtPTLsBGqTqqsqp',
#  'MlSdnScRnnmmDjSdNSdCzvggWzrgzjvfvrgVzW',
#  'gsMljbrjlZlWcWMJrWwTwbmwQbmmLDQQLhwL',
#  'CdgpzdgpgnfThHfFRwhfRf',
#  'SptgpSpnCNpVSGNPvPGSddcMWjMrjqBsJcWqMcBWcVlZ',
#  'JcJLQQFWhQJPJpWcwjHvMQvnnlMvzBHd',
#  'tCtGZrmVRmVGTVTtCfRTCHHNNvdNzmdMvMlNzvwdvw',
#  'CTGGRftfSGtGTGDLbFchSgSWWWcM',
#  'QcMFQrvrQbvtczbVbjbMzZzRpqmDDmqqnNzCDCDC',
#  'SHHfPJssGLPSdHThLhHdRmqNmNssnNmNCNnpjmsn',
#  'LhLJfTdLJwfgPTdfGccrtjcMrccwvcrrFr',
#  'jFLLLqDGjbtqLCChpMMhMBvpwMTmffpZ',
#  'ZnJHRncHHgnrsrZffTdMdMBfmMvfvR',
#  'NWWPnZrVHrZPCDDQtzDCPLCq',
#  'jpFjvBZhDFHZdwcmslcslBLLNl',
#  'dVtTVVCzzfrrMPNLLcnVcPLRns',
#  'CrzWzTqdWtGCzJtbJCrMjjDFHZQjZSpvFGFgHhHp',
#  'JjJqMctnhtDZDQtf',
#  'TrFFlrrCCHPwHwlPHFPzDhsffQQDsVfWwVJQJB',
#  'HHHGdFlHldTpCCFFlLHdCRJccMnqvqMgnNjjMjjvLMLcSv',
# ...

# %%
tst = ['vJrwpWtwJgWrhcsFMMfFFhFp','jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL','PmmdzqPrVvPwwTWBwg','wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn','ttgJtRGJQctTZtZT','CrZsJsPPZsGzwwsLwLmpwMDw']

# %%
list(set(tst[0][:12]).intersection(tst[0][12:]))
# Out:
# ['p']

# %%
tst[0][:int(len(tst[0])/2)]
# Out:
# 'vJrwpWtwJgWr'

# %%
common =[]
for i in lst:
    common.extend((set(i[:int(len(i)/2)]).intersection(i[int(len(i)/2):])))

# %%
len(lst)
# Out:
# 300

# %%
common
# Out:
# ['s',
#  'H',
#  'n',
#  'F',
#  'G',
#  'j',
#  'b',
#  'f',
#  'V',
#  'Q',
#  'm',
#  'S',
#  'z',
#  's',
#  'w',
#  'h',
#  'R',
#  'P',
#  'B',
#  'V',
#  'G',
#  't',
#  'w',
#  'L',
#  'r',
#  'n',
#  'b',
#  'P',
#  'V',
#  'F',
#  'Q',
#  'S',
#  'W',
#  'J',
#  'N',
#  'b',
#  'j',
#  's',
#  'R',
#  'w',
#  'd',
#  'H',
#  'R',
#  'F',
#  'b',
#  'd',
#  'c',
#  'r',
#  'c',
#  'C',
#  'g',
#  'v',
#  'w',
#  'r',
#  'q',
#  'w',
#  'v',
#  'H',
#  'D',
#  'G',
#  'n',
#  'j',
#  'b',
#  'b',
#  'n',
#  'h',
#  'p',
#  'W',
#  'N',
#  's',
#  'M',
#  'j',
#  'Z',
#  'M',
#  'f',
#  'W',
#  'h',
#  's',
#  'h',
#  'l',
#  't',
#  'h',
#  'V',
#  'g',
#  'V',
#  'T',
#  'F',
#  'h',
#  'W',
#  'Q',
#  'h',
#  'L',
#  'T',
#  'r',
#  's',
#  'R',
#  'Z',
#  'P',
#  'm',
#  'M',
#  'z',
#  'G',
#  'z',
#  'T',
#  'g',
#  'T',
#  'j',
#  'W',
#  'S',
#  'n',
#  'j',
#  'Q',
#  'S',
#  'G',
#  'Q',
#  'c',
#  'J',
#  'h',
#  'Q',
#  'n',
#  'm',
#  'c',
#  'Z',
#  'B',
#  'h',
# ...

# %%
common_int =[]

# %%
for a in common:
    if a.islower():
        common_int.append(ord(a)-96)
    else:
        common_int.append((ord(a)-38))

# %%
common_int
# Out:
# [19,
#  34,
#  14,
#  32,
#  33,
#  10,
#  2,
#  6,
#  48,
#  43,
#  13,
#  45,
#  26,
#  19,
#  23,
#  8,
#  44,
#  42,
#  28,
#  48,
#  33,
#  20,
#  23,
#  38,
#  18,
#  14,
#  2,
#  42,
#  48,
#  32,
#  43,
#  45,
#  49,
#  36,
#  40,
#  2,
#  10,
#  19,
#  44,
#  23,
#  4,
#  34,
#  44,
#  32,
#  2,
#  4,
#  3,
#  18,
#  3,
#  29,
#  7,
#  22,
#  23,
#  18,
#  17,
#  23,
#  22,
#  34,
#  30,
#  33,
#  14,
#  10,
#  2,
#  2,
#  14,
#  8,
#  16,
#  49,
#  40,
#  19,
#  39,
#  10,
#  52,
#  39,
#  6,
#  49,
#  8,
#  19,
#  8,
#  12,
#  20,
#  8,
#  48,
#  7,
#  48,
#  46,
#  32,
#  8,
#  49,
#  43,
#  8,
#  38,
#  46,
#  18,
#  19,
#  44,
#  52,
#  42,
#  13,
#  39,
#  26,
#  33,
#  26,
#  46,
#  7,
#  46,
#  10,
#  49,
#  45,
#  14,
#  10,
#  43,
#  45,
#  33,
#  43,
#  3,
#  36,
#  8,
#  43,
#  14,
#  13,
#  3,
#  52,
#  28,
#  8,
#  42,
#  7,
#  46,
#  10,
#  7,
#  38,
#  13,
#  46,
#  23,
#  42,
#  40,
#  42,
#  20,
#  45,
#  52,
#  10,
#  26,
#  36,
#  52,
#  28,
#  42,
# ...

# %%
sum(common_int)
# Out:
# 8176

# %%
tst[:3]
# Out:
# ['vJrwpWtwJgWrhcsFMMfFFhFp',
#  'jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL',
#  'PmmdzqPrVvPwwTWBwg']

# %%
common_3 = []
for i,j in enumerate(lst):
    try:
        common_3.extend(set.intersection(*map(set,lst[3*i:int(3*(i+1))])))
    except:
        pass
common_3
# Out:
# ['b',
#  'R',
#  'g',
#  'M',
#  'j',
#  'Z',
#  'd',
#  'J',
#  'm',
#  'f',
#  'm',
#  'L',
#  'Z',
#  'r',
#  'S',
#  'N',
#  'Q',
#  'C',
#  'd',
#  'W',
#  'V',
#  'T',
#  's',
#  'g',
#  'F',
#  'l',
#  'd',
#  'L',
#  'M',
#  'n',
#  'd',
#  'Z',
#  'Q',
#  'R',
#  'v',
#  'G',
#  'D',
#  'b',
#  'G',
#  't',
#  'N',
#  't',
#  'G',
#  'Q',
#  'g',
#  'v',
#  'L',
#  'v',
#  'g',
#  'c',
#  'j',
#  'W',
#  'd',
#  'V',
#  'P',
#  's',
#  'Z',
#  'C',
#  'W',
#  'p',
#  'n',
#  'M',
#  'd',
#  'f',
#  'Q',
#  'V',
#  'r',
#  'h',
#  'V',
#  'B',
#  'R',
#  'n',
#  'W',
#  'C',
#  'P',
#  'B',
#  'c',
#  'l',
#  'R',
#  'm',
#  's',
#  'N',
#  's',
#  'P',
#  'g',
#  'm',
#  'Q',
#  'Q',
#  'r',
#  'v',
#  'G',
#  'w',
#  'c',
#  'r',
#  'n',
#  'R',
#  'q',
#  'V',
#  'H',
#  'p']

# %%
for a in common_3:
    if a.islower():
        common_int.append(ord(a)-96)
    else:
        common_int.append((ord(a)-38))

# %%
sum(common_int)
# Out:
# 2689

# %%
tst
# Out:
# ['vJrwpWtwJgWrhcsFMMfFFhFp',
#  'jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL',
#  'PmmdzqPrVvPwwTWBwg',
#  'wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn',
#  'ttgJtRGJQctTZtZT',
#  'CrZsJsPPZsGzwwsLwLmpwMDw']
